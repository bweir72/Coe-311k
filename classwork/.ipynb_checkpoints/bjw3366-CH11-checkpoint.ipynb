# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define known data points

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot, using this for the poly fit as well
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)
              

# Polynomial fitting using NumPy's polyfit
degree = 5
coefficients = np.polyfit(x, y, degree)

# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
              
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x_interp)

plt.figure()
plt.scatter(x, y)
plt.plot(x_interp, y_interp, label='CubicSpline')
plt.plot(x_interp, y_pred, label='Polyfit degree 5')
plt.legend()
plt.show()
