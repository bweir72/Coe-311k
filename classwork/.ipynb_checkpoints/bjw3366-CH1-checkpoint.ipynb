# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
x = np.linspace(-10, 10, 2000)
y = np.linspace(-10, 10, 2000)

plt.subplot(4, 1, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'r')

plt.subplot(4, 1, 2)
#plt.plot(x, np.cos(x), 'g')
z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im,
orientation='horizontal')

plt.subplot(4,1,3)
plt.scatter(x,y)

plt.subplot(4,1,4)
plt.hist(x, 50)
plt.show()

plt.show()

# %%
X
# Out:
# array([[-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        ...,
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ]])
