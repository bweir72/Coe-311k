# %%
import numpy as np

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
        
    return x, max_iterations

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
            
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
    return x, max_iterations

# %%
A = np.array([
    [0.582745, 0.48, 0.10, 0., 0.], 
    [0.48, 1.044129, 0.46, 0.10, 0.],
    [0.10, 0.46, 1.10431 , 0.44, 0.10],
    [0., 0.10, 0.44, 0.963889, 0.42],
    [0., 0., 0.10, 0.42, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution_GS, iterations_GS = gauss_seidel(A, b, x0, tol, max_iterations)
solution_J, iterations_J = jacobi(A, b, x0, tol, max_iterations)

print(f"Solution for Gauss-Seidel: {solution_GS}")
print(f"Iterations for Gauss-Seidel: {iterations_GS}")
print(f"\nSolution for Jacobi: {solution_J}")
print(f"Iterations for Jacobi: {iterations_J}")
# Out:
# Solution for Gauss-Seidel: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Iterations for Gauss-Seidel: 20
#
# Solution for Jacobi: [0.34253948 0.34219824 0.34215212 0.34233398 0.34277892]
# Iterations for Jacobi: 100

# %%
# Example usage
A = np.array([[1., 1.], [1., 1.0001]],dtype=float)
b = np.array([1., 1.],dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution_GS, iterations_GS = gauss_seidel(A, b, x0, tol, max_iterations)
solution_J, iterations_J = jacobi(A, b, x0, tol, max_iterations)

print(f"Solution for Gauss-Seidel: {solution_GS}")
print(f"Iterations for Gauss-Seidel: {iterations_GS}")
print(f"\nSolution for Jacobi: {solution_J}")
print(f"Iterations for Jacobi: {iterations_J}")
# Out:
# Solution for Gauss-Seidel: [1. 0.]
# Iterations for Gauss-Seidel: 1
#
# Solution for Jacobi: [0.00498727 0.        ]
# Iterations for Jacobi: 100

# %%
# Example usage
A = np.array([[1., 1.], [1., 1.0001]],dtype=float)
b = np.array([1., 1.0001],dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution_GS, iterations_GS = gauss_seidel(A, b, x0, tol, max_iterations)
solution_J, iterations_J = jacobi(A, b, x0, tol, max_iterations)

print(f"Solution for Gauss-Seidel: {solution_GS}")
print(f"Iterations for Gauss-Seidel: {iterations_GS}")
print(f"\nSolution for Jacobi: {solution_J}")
print(f"Iterations for Jacobi: {iterations_J}")
# Out:
# Solution for Gauss-Seidel: [0.99014933 0.00994967]
# Iterations for Gauss-Seidel: 100
#
# Solution for Jacobi: [0.         0.00498727]
# Iterations for Jacobi: 100

# %%
print(f"A:{A}")
kappa = np.linalg.cond(A,2)
print(kappa)
# Out:
# A:[[1.     1.    ]
#  [1.     1.0001]]
# 40002.00007491187
