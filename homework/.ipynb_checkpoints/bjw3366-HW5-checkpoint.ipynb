# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(0., 1.01, .01)
Y = X + np.random.rand(len(X))

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, b = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

y = m * X + b

plt.figure()
plt.scatter(X,Y)
plt.plot(X,y)
plt.title("My Equations Best Fit Line")
plt.show()
# Out:
# Slope: 0.922466372690679, Intercept: 0.7930689368694671

# %%
xSum = np.sum(X)
ySum = np.sum(Y)
xSquared = X * X
xSqSum = np.sum(xSquared)
xy = X * Y
xySum = np.sum(xy)

mNumerator = (len(X) * xySum) - (xSum * ySum)
mdenom = (len(X) * xSqSum) - (xSum * xSum)
m2 = mNumerator / mdenom
c2 = (ySum - m * xSum) / len(X)

y2 = m2 * X + c2
residual = np.abs(Y - y2)

print("Max residual:", np.max(residual))
print("Min residual:", np.min(residual))

plt.figure()
plt.scatter(X,Y)
plt.plot(X,y2)
plt.title("Predicted Best Fit Line")
plt.show()
# Out:
# Max residual: 0.5159985209364824
# Min residual: 0.002561123274476773
