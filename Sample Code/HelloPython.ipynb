# %% [markdown]
# Hello Python! This is my very fist notebook.

# %%
print("Hello World")
# Out:
# Hello World

# %%
2.4 + 8
# Out:
# 10.4

# %%
name = "Branden"
print(name)
# Out:
# Branden

# %%
a = 7

# %%
print(a)
# Out:
# 7

# %%
type(a)
# Out:
# int

# %%
b = float(a)

# %%
print(a)
print(b)
# Out:
# 7
# 7.0

# %%
5/2
# Out:
# 2.5

# %%
numIn = input("Please enter a value:")
print(numIn)
# Out:
# Please enter a value:Hello World!
# Hello World!

# %%
myfile = open("test.dat", 'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("Hooray!\n")
myfile.close()

# %%
myfile2 = open("test.dat",'r')
content = myfile2.read()
print(content)
myfile2.close()
# Out:
# Hello World!
# Hooray!

# %%
a = 10 
b = 11
if (a < b):
    print("B is greater than A")
# Out:
# B is greater than A

# %%
for i in range(1,10):
    print(i,i**2)
# Out:
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81

# %%
for i in range(1,4):
    for j in range (1,6):
        print(i,j)
        if( j == 5):
            print("\n")
# Out:
# 1 1
# 1 2
# 1 3
# 1 4
# 1 5
#
#
# 2 1
# 2 2
# 2 3
# 2 4
# 2 5
#
#
# 3 1
# 3 2
# 3 3
# 3 4
# 3 5

# %%
mylist = ["Branden", 24, "Blue"]

# %%
for i in mylist:
    print(i, type(i))
# Out:
# Branden <class 'str'>
# 24 <class 'int'>
# Blue <class 'str'>

# %%
print(mylist[:-1])
# Out:
# ['Branden', 24]

# %%
print("Branden" in mylist)
print("Conner" in mylist)
# Out:
# True
# False

# %%
def calc_hyp(a,b):
    h = (a*a + b*b) ** 0.5
    return h

# %%
my_h = calc_hyp(a,b)
print(my_h)
# Out:
# 14.866068747318506
