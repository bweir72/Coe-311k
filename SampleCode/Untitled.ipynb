# %%
import numpy as np

# %%
A = np.array([[2,1],[1,1]])
B = np.array([[2,4],[1,2]])
print(np.linalg.det(A))
print(np.linalg.det(B))
# Out:
# 1.0
# 0.0

# %%
# A is invertible, unique solution, not flipped
# B dont know

# %%
Ainv = np.linalg.inv(A)
print(Ainv)
# Out:
# [[ 1. -1.]
#  [-1.  2.]]

# %%
print(f"A:{A}")
kappa = np.linalg.cond(A,2)
print(kappa)
# Out:
# A:[[2 1]
#  [1 1]]
# 6.854101966249688
